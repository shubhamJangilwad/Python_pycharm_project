# %%
def position(a,b):
    return a+b
result = position(a=2,b=3)
print(result)
# Out:
# 5

# %%
def keyword(a,b):
    return a - b
result = keyword(b= 3,a=5)
print(result)
# Out:
# 2

# %%
def default(name = "shubham"):
    return name
result = default("hanumant")
print(result)
# Out:
# hanumant

# %%
def vlargs(*a):
    for i in a:
        print(i)
vlargs(1,2,3,4)
# Out:
# 1
# 2
# 3
# 4
